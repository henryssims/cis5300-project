# %%
import pandas as pd

# %%
import pandas as pd

splits = {'train': 'wiki.full.aner.ori.train.95.tsv', 'validation': 'wiki.full.aner.ori.valid.95.tsv', 'test': 'wiki.full.aner.ori.test.95.tsv'}
train = pd.read_csv("hf://datasets/bogdancazan/wikilarge-text-simplification/" + splits["train"], sep="\t")
val = pd.read_csv("hf://datasets/bogdancazan/wikilarge-text-simplification/" + splits["validation"], sep="\t")
test = pd.read_csv("hf://datasets/bogdancazan/wikilarge-text-simplification/" + splits["test"], sep="\t")

# %%
train
# Out:
#                                                    Normal  \
# 0       there is manuscript evidence that austen conti...
# 1       in a remarkable comparative analysis mandaean ...
# 2       before persephone was released to hermes who h...
# 3       geneva lrb rrb is the second most populous cit...
# 4       when japan earned another race on the f schedu...
# ...                                                   ...
# 148838  tijs michiel verwest was born in breda north b...
# 148839  these structures form at the high pressure dep...
# 148840  saint maixant is a commune in the gironde depa...
# 148841  boulogne billancourt is the most populous subu...
# 148842  overall juventus have won official competition...
#
#                                                    Simple
# 0       there is some proof that austen continued to w...
# 1       mandaean scholar s ve s derberg showed that ma...
# 2       when demeter went to the underworld to rescue ...
# 3       the city s main newspaper is the tribune de ge...
# 4       when japan was added back to the f schedule te...
# ...                                                   ...
# 148838         he was born on january in the netherlands.
# 148839  these structures form at the high pressure dep...
# 148840  saint maixant gironde is a commune. it is foun...
# 148841  consequently boulogne billancourt is one of th...
# 148842  the club is the most successful team in the hi...
#
# [148843 rows x 2 columns]

# %%
val
# Out:
#                                                 Normal  \
# 0    upper sorbian is a minority language spoken by...
# 1    relation to the nobel prize the sveriges riksb...
# 2    a shoe is an item of footwear evolved at first...
# 3    helicopter rotor the rotary wing lrb s rrb of ...
# 4    in it had over students studying academic prog...
# ..                                                 ...
# 489  moody bible institute lrb mbi rrb was founded ...
# 490                we ll do our best whate er the test
# 491  sedimentary rock is one of the three main rock...
# 492  east timor also known as timor leste lrb tetum...
# 493  one of the largest of the classic maya cities ...
#
#                                                 Simple
# 0    there are around speakers of upper sorbian liv...
# 1    the sveriges riksbank prize in economic scienc...
# 2                  a shoe is also an item of clothing.
# 3    rotor a former radar project in the uk followi...
# 4    in it had over students studying academic prog...
# ..                                                 ...
# 489  in it was started by evangelist and businessma...
# 490                 well do our best whate er the test
# 491  other types of rock are igneous rock and metam...
# 492  the democratic republic of east timor or timor...
# 493  the ruins are on lowland rainforest but tikal ...
#
# [494 rows x 2 columns]

# %%
test
# Out:
#                                                 Normal  \
# 0    his next work saturday follows an especially e...
# 1    the tarantula the trickster character spun a b...
# 2            there he died six weeks later on january.
# 3    they are culturally akin to the coastal people...
# 4    following the drummers are dancers who often p...
# ..                                                 ...
# 186  his real date of birth was never recorded but ...
# 187  this quantitative measure indicates how much o...
# 188  there he had one daughter later baptized as ma...
# 189  during an interview edward gorey mentioned tha...
# 190  gable also earned an academy award nomination ...
#
#                                                 Simple
# 0    his next work at saturday will be a successful...
# 1    the tarantuala the trickster spun a black chor...
# 2               he died six weeks later on january th.
# 3    their culture is similar to the culture of the...
# 4    the drummers are dancers and often play the so...
# ..                                                 ...
# 186  since his actual date of birth was not recorde...
# 187  this quantitative measure indicates how much o...
# 188  he had one daughter named mary ann fisher powe...
# 189  during an interview edward gorey said that baw...
# 190  gable also earned an academy award nomination ...
#
# [191 rows x 2 columns]

# %%
hi = pd.read_csv("data/train.csv")

# %%
hi.loc[0]
# Out:
# Normal    there is manuscript evidence that austen conti...
# Simple    there is some proof that austen continued to w...
# Name: 0, dtype: object
